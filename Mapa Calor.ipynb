# %% [markdown]
# <a href="https://colab.research.google.com/github/irehdezrAnalisisDatos/Ejercicio-1/blob/main/Mapa%20Calor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Leer el archivo CSV

# %%
df = pd.read_csv('/content/School-Age-Digital-Connectivity - Primary.csv')
contingency_table = pd.crosstab(df['Income Group'], df['Region'])
#Crear el mapa de calor
plt.figure(figsize=(10, 7))
sns.heatmap(contingency_table, annot=True, cmap="PiYG")
# Mostrar el gráfico
plt.title('Mapa de Calor de Income Group vs Residence-Urban')
plt.show()
